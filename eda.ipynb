# %%
import pandas as pd

df = pd.read_csv('file.csv')

# %%
# Basic info
print(df.info())

# Preview data
print(df.head())

# Summary statistics for numeric columns
print(df.describe())

# Check target distribution
print(df['status'].value_counts(normalize=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nomor             150 non-null    int64
#  1   nama              150 non-null    object
#  2   nik               150 non-null    int64
#  3   akte_lahir        150 non-null    bool
#  4   akte_kk           150 non-null    bool
#  5   foto_rumah        150 non-null    bool
#  6   rekening_listrik  150 non-null    bool
#  7   ijazah_sma        150 non-null    bool
#  8   nilai_raport      150 non-null    int64
#  9   pas_foto          150 non-null    bool
#  10  nilai_un          150 non-null    int64
#  11  prestasi          150 non-null    bool
#  12  kip               150 non-null    bool
#  13  kks               150 non-null    bool
#  14  pkh               150 non-null    bool
#  15  bdt               150 non-null    bool
#  16  kartu_miskin      150 non-null    bool
#  17  sktm              150 non-null    bool
#  18  penghasilan_ortu  150 non-null    bool
#  19  status            150 non-null    int64
# dtypes: bool(14), int64(5), object(1)
# memory usage: 9.2+ KB
# None
#    nomor          nama               nik  akte_lahir  akte_kk  foto_rumah  \
# 0      1  Budi Santoso  1234567890123456        True     True        True
# 1      2   Siti Aminah  2345678901234567        True     True       False
# 2      3   Joko Susilo  3456789012345678       False     True       False
# 3      4  Dewi Lestari  4567890123456789        True    False        True
# 4      5   Ahmad Fauzi  5678901234567890        True     True        True
#
#    rekening_listrik  ijazah_sma  nilai_raport  pas_foto  nilai_un  prestasi  \
# 0             False        True            85      True        75     False
# 1              True        True            90      True        80      True
# 2             False        True            78      True        70     False
# 3              True        True            92      True        85      True
# 4             False       False            80      True        72     False
#
#      kip    kks    pkh    bdt  kartu_miskin  sktm  penghasilan_ortu  status
# 0  False   True  False  False          True  True              True       1
# 1  False  False   True  False          True  True              True       1
# 2   True  False  False   True          True  True              True       0
# 3  False  False  False   True          True  True              True       1
# 4  False   True  False  False          True  True              True       1
#             nomor           nik  nilai_raport    nilai_un      status
# count  150.000000  1.500000e+02    150.000000  150.000000  150.000000
# mean    75.500000  4.624063e+15     82.120000   74.786667    0.666667
# std     43.445368  2.917504e+15      7.936763    8.848150    0.472984
# min      1.000000  1.122334e+13     69.000000   61.000000    0.000000
# 25%     38.250000  2.065957e+15     75.000000   67.250000    0.000000
# 50%     75.500000  4.792340e+15     83.500000   76.000000    1.000000
# 75%    112.750000  7.086401e+15     88.000000   81.000000    1.000000
# max    150.000000  9.900112e+15     95.000000   90.000000    1.000000
# status
# 1    0.666667
# 0    0.333333
# Name: proportion, dtype: float64

# %%
print(df.isnull().sum())
# Out:
# nomor               0
# nama                0
# nik                 0
# akte_lahir          0
# akte_kk             0
# foto_rumah          0
# rekening_listrik    0
# ijazah_sma          0
# nilai_raport        0
# pas_foto            0
# nilai_un            0
# prestasi            0
# kip                 0
# kks                 0
# pkh                 0
# bdt                 0
# kartu_miskin        0
# sktm                0
# penghasilan_ortu    0
# status              0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df.drop(columns=['nama']).hist(bins=20, figsize=(15,12))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Correlation matrix
corr = df.drop(columns=['nama']).corr()

plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
[(i, df[i].nunique()) for i in df.columns]
# Out:
# [('nomor', 150),
#  ('nama', 149),
#  ('nik', 149),
#  ('akte_lahir', 2),
#  ('akte_kk', 2),
#  ('foto_rumah', 2),
#  ('rekening_listrik', 2),
#  ('ijazah_sma', 2),
#  ('nilai_raport', 27),
#  ('pas_foto', 2),
#  ('nilai_un', 30),
#  ('prestasi', 2),
#  ('kip', 2),
#  ('kks', 2),
#  ('pkh', 2),
#  ('bdt', 2),
#  ('kartu_miskin', 2),
#  ('sktm', 2),
#  ('penghasilan_ortu', 2),
#  ('status', 2)]

# %%
df.head()
# Out:
#    nomor          nama               nik  akte_lahir  akte_kk  foto_rumah  \
# 0      1  Budi Santoso  1234567890123456        True     True        True
# 1      2   Siti Aminah  2345678901234567        True     True       False
# 2      3   Joko Susilo  3456789012345678       False     True       False
# 3      4  Dewi Lestari  4567890123456789        True    False        True
# 4      5   Ahmad Fauzi  5678901234567890        True     True        True
#
#    rekening_listrik  ijazah_sma  nilai_raport  pas_foto  nilai_un  prestasi  \
# 0             False        True            85      True        75     False
# 1              True        True            90      True        80      True
# 2             False        True            78      True        70     False
# 3              True        True            92      True        85      True
# 4             False       False            80      True        72     False
#
#      kip    kks    pkh    bdt  kartu_miskin  sktm  penghasilan_ortu  status
# 0  False   True  False  False          True  True              True       1
# 1  False  False   True  False          True  True              True       1
# 2   True  False  False   True          True  True              True       0
# 3  False  False  False   True          True  True              True       1
# 4  False   True  False  False          True  True              True       1
